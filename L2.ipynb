# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

df = pd.read_csv("Twitch_global_data.csv")

df
# Out:
#      year  Month  Hours_watched  Avg_viewers  Peak_viewers   Streams  \
# 0    2016      1      480241904       646355       1275257   7701675
# 1    2016      2      441859897       635769       1308032   7038520
# 2    2016      3      490669308       660389       1591551   7390957
# 3    2016      4      377975447       525696       1775120   6869719
# 4    2016      5      449836631       605432       1438962   7535519
# ..    ...    ...            ...          ...           ...       ...
# 100  2024      5     1727139900      2324548       4032587  22686570
# 101  2024      6     1617653502      2249865       4560410  22209935
# 102  2024      7     1660370134      2234683       6872963  23309553
# 103  2024      8     1711442710      2303422       4159346  23399616
# 104  2024      9     1698990192      2362990       4343770  21730541
#
#      Avg_channels  Games_streamed  Viewer_ratio
# 0           20076           12149         29.08
# 1           20427           12134         28.98
# 2           20271           12234         28.92
# 3           16791           12282         28.80
# 4           19394           12424         28.85
# ..            ...             ...           ...
# 100         91550           46363         25.90
# 101         92133           46752         24.78
# 102         93039           46904         24.24
# 103         93682           46965         25.14
# 104         90841           45635         26.46
#
# [105 rows x 9 columns]

# %%
import importlib.metadata

for package in importlib.metadata.distributions():
    print(package.metadata["Name"], package.version)
# Out:
# jupyterlab_git 0.54.1
# gitdb 4.0.12
# prompt_toolkit 3.0.53
# nest-asyncio2 1.7.2
# urllib3 2.7.0
# charset-normalizer 3.5.1
# GitPython 3.1.62
# nbconvert 7.17.1
# Pygments 2.21.0
# comm 0.2.3
# soupsieve 2.9.2
# jsonpointer 3.1.1
# ipython 9.17.1
# attrs 26.1.0
# rfc3339-validator 0.1.4
# terminado 0.18.1
# anyio 4.15.1
# jupyterlab_server 2.28.0
# uri-template 1.3.0
# nbclient 0.11.0
# notebook_shim 0.2.4
# rfc3987-syntax 1.1.0
# typing_extensions 4.16.0
# httpx 0.28.1
# websocket-client 1.9.2
# requests 2.34.2
# rpds-py 2026.6.3
# async-lru 2.3.0
# jedi 0.20.0
# PyYAML 6.0.3
# jupyter_builder 1.2.3
# jupyterlab_pygments 0.3.0
# executing 2.2.1
# smmap 5.0.3
# stack-data 0.6.3
# tornado 6.5.8
# jupyter_server 2.21.0
# asttokens 3.0.2
# wcwidth 0.8.3
# babel 2.18.0
# fastjsonschema 2.22.2
# jupyter-events 0.12.1
# ptyprocess 0.7.0
# jupyterlab 4.6.3
# psutil 7.2.2
# parso 0.8.7
# beautifulsoup4 4.15.0
# pyzmq 27.2.0
# Jinja2 3.1.6
# mistune 3.3.4
# nbformat 5.11.1
# colorama 0.4.6
# httpcore 1.0.9
# platformdirs 4.11.8
# pycparser 3.0
# defusedxml 0.7.1
# json5 0.15.0
# tzdata 2026.3
# cffi 2.1.1
# python-json-logger 4.2.0
# traitlets 5.16.1
# ipykernel 7.3.0
# jupyter_client 8.10.0
# idna 3.19
# jupyter_core 5.9.1
# jupyter_server_terminals 0.5.4
# jsonschema-specifications 2025.9.1
# jupyter-lsp 2.3.1
# pandocfilters 1.5.1
# certifi 2026.7.22
# python-dateutil 2.9.0.post0
# bleach 6.4.0
# nbdime 4.0.4
# arrow 1.4.0
# tinycss2 1.5.1
# lark 1.3.1
# argon2-cffi-bindings 26.1.0
# Send2Trash 2.1.0
# matplotlib-inline 0.2.2
# debugpy 1.8.21
# MarkupSafe 3.0.3
# webencodings 0.6.1
# rfc3986-validator 0.1.1
# webcolors 25.10.0
# ipython_pygments_lexers 1.1.1
# pexpect 4.9.0
# pure_eval 0.2.3
# referencing 0.37.0
# fqdn 1.5.1
# h11 0.16.0
# argon2-cffi 25.1.0
# isoduration 20.11.0
# prometheus_client 0.26.0
# jupyterlab-git-core 0.54.1
# packaging 26.3
# six 1.17.0
# jsonschema 4.26.0
# pip 26.2.1
# pandas 3.0.6
# numpy 2.5.3
# kiwisolver 1.5.1
# pyparsing 3.3.3
# pillow 12.3.0
# contourpy 1.4.0
# matplotlib 3.11.2
# scipy 1.18.1
# cycler 0.12.1
# seaborn 0.13.2
# fonttools 4.66.0
